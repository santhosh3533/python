# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../../Pierian_Data_Logo.png' /></a>
# ___

# %% [markdown]
# # SF Salaries Exercise
#
# We will be using the [SF Salaries Dataset](https://www.kaggle.com/kaggle/sf-salaries) from Kaggle! Just follow along and complete the tasks outlined in bold below. The tasks will get harder and harder as you go along.

# %% [markdown]
# ** Import pandas as pd.**

# %%
import pandas as pd

# %% [markdown]
# ** Read Salaries.csv as a dataframe called sal.**

# %%
sal = pd.read_csv('Salaries-1.csv')
sal
# Out:
#             Id          EmployeeName  \
# 0            1        NATHANIEL FORD
# 1            2          GARY JIMENEZ
# 2            3        ALBERT PARDINI
# 3            4     CHRISTOPHER CHONG
# 4            5       PATRICK GARDNER
# 5            6        DAVID SULLIVAN
# 6            7             ALSON LEE
# 7            8         DAVID KUSHNER
# 8            9        MICHAEL MORRIS
# 9           10    JOANNE HAYES-WHITE
# 10          11         ARTHUR KENNEY
# 11          12      PATRICIA JACKSON
# 12          13     EDWARD HARRINGTON
# 13          14           JOHN MARTIN
# 14          15        DAVID FRANKLIN
# 15          16       RICHARD CORRIEA
# 16          17              AMY HART
# 17          18        SEBASTIAN WONG
# 18          19            MARTY ROSS
# 19          20         ELLEN MOFFATT
# 20          21            VENUS AZAR
# 21          22          JUDY MELINEK
# 22          23         GEORGE GARCIA
# 23          24         VICTOR WYRSCH
# 24          25       JOSEPH DRISCOLL
# 25          26          GREGORY SUHR
# 26          27           JOHN HANLEY
# 27          28        RAYMOND GUZMAN
# 28          29        DENISE SCHMITT
# 29          30         MONICA FIELDS
# ...        ...                   ...
# 134149  134150      September M Rose
# 134150  134151        Robert L Bates
# 134151  134152     Shirley D Viernes
# 134152  134153       Matthew D Welch
# 134153  134154            Baona Zhou
# 134154  134155         Roy Castrejon
# 134155  134156       Huynhnga Nguyen
# 134156  134157        Patrick E Shea
# 134157  134158         Mario Jimenez
# 134158  134159    Charles D Kesecker
# 134159  134160     Glenn M Galliguez
# 134160  134161     Shirnella L Munar
# 134161  134162          Oscar Flores
# 134162  134163         Thomas E Kent
# 134163  134164      Sebastian Torres
# 134164  134165         Tenzin Legmon
# 134165  134166       Melyssa C Preza
# 134166  134167       Liao Liang Situ
# 134167  134168        Christina Chen
# 134168  134169        Sandra C Avila
# 134169  134170             Thom A Lo
# 134170  134171  Charlene S Weah Weah
# 134171  134172          Doris Rendon
# 134172  134173     Shirley A Hubbard
# 134173  134174      Blanca L Montoya
# 134174  134175            Cui Hua Wu
# 134175  134176        Anthony Martin
# 134176  134177     Maurice Valentine
# 134177  134178        Maria L Najjar
# 134178  134179         Crystal Cheng
#
#                                                 JobTitle    BasePay  \
# 0         GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                        CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                        CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                   WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4           DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# 5                              ASSISTANT DEPUTY CHIEF II  118602.00
# 6                     BATTALION CHIEF, (FIRE DEPARTMENT)   92492.01
# 7                         DEPUTY DIRECTOR OF INVESTMENTS  256576.96
# 8                     BATTALION CHIEF, (FIRE DEPARTMENT)  176932.64
# 9                 CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)  285262.00
# 10      ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)  194999.39
# 11                       CAPTAIN III (POLICE DEPARTMENT)   99722.00
# 12                           EXECUTIVE CONTRACT EMPLOYEE  294580.02
# 13                                     DEPARTMENT HEAD V  271329.03
# 14                    BATTALION CHIEF, (FIRE DEPARTMENT)  174872.64
# 15                    COMMANDER III, (POLICE DEPARTMENT)  198778.01
# 16                                     DEPARTMENT HEAD V  268604.57
# 17                 CAPTAIN, EMERGENCYCY MEDICAL SERVICES  140546.87
# 18                    BATTALION CHIEF, (FIRE DEPARTMENT)  168692.63
# 19                            ASSISTANT MEDICAL EXAMINER  257510.59
# 20                            ASSISTANT MEDICAL EXAMINER  257510.48
# 21                            ASSISTANT MEDICAL EXAMINER  257510.44
# 22                             CAPTAIN, FIRE SUPPRESSION  140546.88
# 23                    BATTALION CHIEF, (FIRE DEPARTMENT)  168692.63
# 24                             CAPTAIN, FIRE SUPPRESSION  140546.86
# 25                                       CHIEF OF POLICE  256470.41
# 26                             CAPTAIN, FIRE SUPPRESSION   92080.80
# 27                    BATTALION CHIEF, (FIRE DEPARTMENT)  168692.59
# 28                  DEPUTY CHIEF III (POLICE DEPARTMENT)  261717.60
# 29          DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  246225.60
# ...                                                  ...        ...
# 134149                        Hospital Eligiblity Worker   59370.37
# 134150                                            Porter   54389.23
# 134151                                            Porter   54703.01
# 134152                           Parking Control Officer   57246.57
# 134153                                         Custodian   54703.00
# 134154                               Stationary Engineer   57849.45
# 134155                                     Account Clerk   57531.15
# 134156                                       Librarian 1   59711.19
# 134157                                   Health Worker 2   56744.24
# 134158                            Transit Fare Inspector   55358.41
# 134159                                  Transit Operator   47963.00
# 134160                                      Senior Clerk   54236.91
# 134161                                   General Laborer   56068.94
# 134162                         HSA Sr Eligibility Worker   56155.59
# 134163                                  Transit Operator   50010.14
# 134164                            Patient Care Assistant   49949.20
# 134165                         HSA Sr Eligibility Worker   53604.42
# 134166                                  Transit Operator   53178.43
# 134167                                 HSA Social Worker   57272.41
# 134168                             Animal Care Attendant   56251.38
# 134169                       Aquatics Facility Asst Supv   55649.03
# 134170                     Medical Evaluations Assistant   57303.53
# 134171                                         Custodian   54703.02
# 134172                                  Transit Operator   46072.58
# 134173                           Parking Control Officer   57229.26
# 134174                                         Custodian   50386.50
# 134175                                            Porter   54703.00
# 134176                                    Deputy Sheriff   57616.74
# 134177                           Parking Control Officer   57343.78
# 134178                             Assistant Storekeeper   43223.80
#
#         OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  \
# 0              0.00  400184.25       NaN  567595.43         567595.43  2011
# 1         245131.88  137811.38       NaN  538909.28         538909.28  2011
# 2         106088.18   16452.60       NaN  335279.91         335279.91  2011
# 3          56120.71  198306.90       NaN  332343.61         332343.61  2011
# 4           9737.00  182234.59       NaN  326373.19         326373.19  2011
# 5           8601.00  189082.74       NaN  316285.74         316285.74  2011
# 6          89062.90  134426.14       NaN  315981.05         315981.05  2011
# 7              0.00   51322.50       NaN  307899.46         307899.46  2011
# 8          86362.68   40132.23       NaN  303427.55         303427.55  2011
# 9              0.00   17115.73       NaN  302377.73         302377.73  2011
# 10         71344.88   33149.90       NaN  299494.17         299494.17  2011
# 11         87082.62  110804.30       NaN  297608.92         297608.92  2011
2014
#
#         Notes         Agency  Status
# 0         NaN  San Francisco     NaN
# 1         NaN  San Francisco     NaN
# 2         NaN  San Francisco     NaN
# 3         NaN  San Francisco     NaN
# 4         NaN  San Francisco     NaN
# 5         NaN  San Francisco     NaN
# 6         NaN  San Francisco     NaN
# 7         NaN  San Francisco     NaN
# 8         NaN  San Francisco     NaN
# 9         NaN  San Francisco     NaN
# 10        NaN  San Francisco     NaN
# 11        NaN  San Francisco     NaN
# 12        NaN  San Francisco     NaN
# 13        NaN  San Francisco     NaN
# 14        NaN  San Francisco     NaN
# 15        NaN  San Francisco     NaN
# 16        NaN  San Francisco     NaN
# 17        NaN  San Francisco     NaN
# 18        NaN  San Francisco     NaN
# 19        NaN  San Francisco     NaN
# 20        NaN  San Francisco     NaN
# 21        NaN  San Francisco     NaN
# 22        NaN  San Francisco     NaN
# 23        NaN  San Francisco     NaN
# 24        NaN  San Francisco     NaN
# 25        NaN  San Francisco     NaN
# 26        NaN  San Francisco     NaN
# 27        NaN  San Francisco     NaN
# 28        NaN  San Francisco     NaN
# 29        NaN  San Francisco     NaN
# ...       ...            ...     ...
# 134149    NaN  San Francisco     NaN
# 134150    NaN  San Francisco     NaN
# 134151    NaN  San Francisco     NaN
# 134152    NaN  San Francisco     NaN
# 134153    NaN  San Francisco     NaN
# 134154    NaN  San Francisco     NaN
# 134155    NaN  San Francisco     NaN
# 134156    NaN  San Francisco     NaN
# 134157    NaN  San Francisco     NaN
# 134158    NaN  San Francisco     NaN
# 134159    NaN  San Francisco     NaN
# 134160    NaN  San Francisco     NaN
# 134161    NaN  San Francisco     NaN
# 134162    NaN  San Francisco     NaN
# 134163    NaN  San Francisco     NaN
# 134164    NaN  San Francisco     NaN
# 134165    NaN  San Francisco     NaN
# 134166    NaN  San Francisco     NaN
# 134167    NaN  San Francisco     NaN
# 134168    NaN  San Francisco     NaN
# 134169    NaN  San Francisco     NaN
# 134170    NaN  San Francisco     NaN
# 134171    NaN  San Francisco     NaN
# 134172    NaN  San Francisco     NaN
# 134173    NaN  San Francisco     NaN
# 134174    NaN  San Francisco     NaN
# 134175    NaN  San Francisco     NaN
# 134176    NaN  San Francisco     NaN
# 134177    NaN  San Francisco     NaN
# 134178    NaN  San Francisco     NaN
#
# [134179 rows x 13 columns]

# %% [markdown]
# ** Check the head of the DataFrame. **

# %%
sal.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN
# 1  2011    NaN  San Francisco     NaN
# 2  2011    NaN  San Francisco     NaN
# 3  2011    NaN  San Francisco     NaN
# 4  2011    NaN  San Francisco     NaN

# %% [markdown]
# ** Use the .info() method to find out how many entries there are.**

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134179 entries, 0 to 134178
# Data columns (total 13 columns):
# Id                  134179 non-null int64
# EmployeeName        134179 non-null object
# JobTitle            134179 non-null object
# BasePay             133574 non-null float64
# OvertimePay         134179 non-null float64
# OtherPay            134179 non-null float64
# Benefits            98020 non-null float64
# TotalPay            134179 non-null float64
# TotalPayBenefits    134179 non-null float64
# Year                134179 non-null int64
# Notes               0 non-null float64
# Agency              134179 non-null object
# Status              0 non-null float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 13.3+ MB

# %% [markdown]
# **What is the average BasePay ?**

# %%
sal['BasePay'].mean()
# Out:
# 71043.41098215223

# %% [markdown]
# ** What is the highest amount of OvertimePay in the dataset ? **

# %%
sal['OverTimePay'].max()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /srv/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'OverTimePay'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-a58301513397> in <module>()
# ----> 1 sal['OverTimePay'].max()
#
# /srv/conda/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2683             return self._getitem_multilevel(key)
#    2684         else:
# -> 2685             return self._getitem_column(key)
#    2686
#    2687     def _getitem_column(self, key):
#
# /srv/conda/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2690         # get column
#    2691         if self.columns.is_unique:
# -> 2692             return self._get_item_cache(key)
#    2693
#    2694         # duplicate columns & possible reduce dimensionality
#
# /srv/conda/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2484         res = cache.get(item)
#    2485         if res is None:
# -> 2486             values = self._data.get(item)
#    2487             res = self._box_item_values(item, values)
#    2488             cache[item] = res
#
# /srv/conda/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /srv/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
# -> 3065                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3066
#    3067         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'OverTimePay'

# %% [markdown]
# ** What is the job title of  JOSEPH DRISCOLL ? Note: Use all caps, otherwise you may get an answer that doesn't match up (there is also a lowercase Joseph Driscoll). **

# %%
# Out:
# 24    CAPTAIN, FIRE SUPPRESSION
# Name: JobTitle, dtype: object

# %% [markdown]
# ** How much does JOSEPH DRISCOLL make (including benefits)? **

# %%
# Out:
# 24    270324.91
# Name: TotalPayBenefits, dtype: float64

# %% [markdown]
# ** What is the name of highest paid person (including benefits)?**

# %%
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18          0.0  400184.25       NaN  567595.43         567595.43
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN

# %% [markdown]
# ** What is the name of lowest paid person (including benefits)? Do you notice something strange about how much he or she is paid?**

# %%
# Out:
#             Id EmployeeName                    JobTitle  BasePay  OvertimePay  \
# 148653  148654    Joe Lopez  Counselor, Log Cabin Ranch      0.0          0.0
#
#         OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# 148653   -618.13       0.0   -618.13           -618.13  2014    NaN
#
#                Agency  Status
# 148653  San Francisco     NaN

# %% [markdown]
# ** What was the average (mean) BasePay of all employees per year? (2011-2014) ? **

# %%
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %% [markdown]
# ** How many unique job titles are there? **

# %%
# Out:
# 2159

# %% [markdown]
# ** What are the top 5 most common jobs? **

# %%
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64

# %% [markdown]
# ** How many Job Titles were represented by only one person in 2013? (e.g. Job Titles with only one occurence in 2013?) **

# %%
# Out:
# 202

# %% [markdown]
# ** How many people have the word Chief in their job title? (This is pretty tricky) **

# %%
# Out:
# 423

# %% [markdown]
# ** Bonus: Is there a correlation between length of the Job Title string and Salary? **

# %%
# Out:
#                   title_len  TotalPayBenefits
# title_len          1.000000         -0.036878
# TotalPayBenefits  -0.036878          1.000000

# %% [markdown]
# # Great Job!
